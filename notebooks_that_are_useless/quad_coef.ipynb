# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a, b, c = 3, -5, -50
f = lambda x: a * x ** 2 + b * x + c

x = np.arange(-100, 100)[:, np.newaxis]
y = f(x) + np.random.randn(x.shape[0], 1) * 100

# %%
plt.scatter(x, y);

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(300, activation='relu'))
model.add(Dense(300, activation='relu'))
model.add(Dense(300, activation='relu'))
model.add(Dense(1))
model.compile('adam', loss='mse')

# %%
model.fit(x, y, epochs=100, shuffle=True)
# Out:
# Epoch 1/100
# 200/200 [==============================] - 0s 222us/step - loss: 10905318.5200
# Epoch 2/100
# 200/200 [==============================] - 0s 171us/step - loss: 10905281.4000
# Epoch 3/100
# 200/200 [==============================] - 0s 180us/step - loss: 10989598.2200
# Epoch 4/100
# 200/200 [==============================] - 0s 177us/step - loss: 10958804.3200
# Epoch 5/100
# 200/200 [==============================] - 0s 174us/step - loss: 10892390.2000
# Epoch 6/100
# 200/200 [==============================] - 0s 161us/step - loss: 10891634.9600
# Epoch 7/100
# 200/200 [==============================] - 0s 175us/step - loss: 11047452.5000
# Epoch 8/100
# 200/200 [==============================] - 0s 189us/step - loss: 10841607.4000
# Epoch 9/100
# 200/200 [==============================] - 0s 167us/step - loss: 10641163.5200
# Epoch 10/100
# 200/200 [==============================] - 0s 154us/step - loss: 10507038.6000
# Epoch 11/100
# ...

# %%
plt.plot(x, y, c='blue')
plt.plot(x, model.predict(x), c='red')

# %%
x1 = x ** 2
x2 = x
x3 = np.ones_like(x)
X = np.array([x1, x2, x3]).squeeze().T

# %%
W = np.linalg.pinv(X.T @ X)

# %%
W @ X.T @ y
# Out:
# array([[  2.99749429],
#        [ -5.05144797],
#        [-35.8496796 ]])

# %%
from nn import NeuralNetwork, Layer, Quadratic, MSE

# %%
xt = X[:, :-1]
xn = (xt - xt.mean()) / xt.std()

# %%
model = NeuralNetwork(n_iterations=100000, learning_rate=0.05)
model.add(Layer(2, 1))
model.fit(xn, y)
# Out:
# 0: MSE=35851789263.95593
# 100: MSE=13581536.432352759
# 200: MSE=13503026.704784721
# 300: MSE=13425121.594028687
# 400: MSE=13347733.712580992
# 500: MSE=13270859.626430474
# 600: MSE=13194495.924376255
# 700: MSE=13118639.217865178
# 800: MSE=13043286.140841525
# 900: MSE=12968433.349597447
# 1000: MSE=12894077.522624815
# 1100: MSE=12820215.360467656
# 1200: MSE=12746843.585575856
# 1300: MSE=12673958.942159679
# 1400: MSE=12601558.196045272
# 1500: MSE=12529638.134531185
# 1600: MSE=12458195.566245837
# 1700: MSE=12387227.321005875
# 1800: MSE=12316730.249675428
# 1900: MSE=12246701.224026512
# 2000: MSE=12177137.1366001
# 2100: MSE=12108034.900568258
# 2200: MSE=12039391.449597262
# 2300: MSE=11971203.737711359
# 2400: MSE=11903468.739157785
# 2500: MSE=11836183.448272403
# 2600: MSE=11769344.879346272
# 2700: MSE=11702950.066493342
# 2800: MSE=11636996.06351866
# 2900: MSE=11571479.943787772
# 3000: MSE=11506398.800096769
# 3100: MSE=11441749.744543266
# ...

# %%
plt.plot(x, y, c='blue');
plt.plot(x, model.predict(xn), c='red');
