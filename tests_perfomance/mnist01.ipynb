# %%
import sys
sys.path.append('..')
from nn import *
from viz import plot_history
from tools import train_test_split

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mnist01 = np.load('datasets/mnist01.npz')
X, y= mnist01['X'], mnist01['y']

# %%
plt.imshow(X[0]);

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)
X_train = (X_train.astype(np.float32) / 255.0)
X_test = ( X_test.astype(np.float32) / 255.0)

# %%
mod = NeuralNetwork(loss='binary_crossentropy', optimizer='gd', verbose=True, verbose_step=1)
mod.add(Flatten())
mod.add(Dense(784, activation='relu'))
mod.add(Dense(784, activation='relu'))
mod.add(Dense(1, activation='sigmoid'))

# %%
h = mod.fit(X_train, y_train, X_test, y_test, n_epochs=10, batch_size=128, metrics=['accuracy'])
plot_history(h)
# Out:
# [    1/10]: loss=0.34909 val_loss=0.34271 accuracy=0.99410 val_accuracy=0.99495
# [    2/10]: loss=0.03038 val_loss=0.03134 accuracy=0.99674 val_accuracy=0.99621
# [    3/10]: loss=0.01464 val_loss=0.01573 accuracy=0.99779 val_accuracy=0.99653
# [    4/10]: loss=0.01054 val_loss=0.01158 accuracy=0.99810 val_accuracy=0.99653
# [    5/10]: loss=0.00863 val_loss=0.00962 accuracy=0.99821 val_accuracy=0.99653
# [    6/10]: loss=0.00750 val_loss=0.00844 accuracy=0.99832 val_accuracy=0.99716
# [    7/10]: loss=0.00673 val_loss=0.00765 accuracy=0.99832 val_accuracy=0.99716
# [    8/10]: loss=0.00616 val_loss=0.00706 accuracy=0.99842 val_accuracy=0.99716
# [    9/10]: loss=0.00572 val_loss=0.00661 accuracy=0.99863 val_accuracy=0.99716
# [   10/10]: loss=0.00537 val_loss=0.00624 accuracy=0.99863 val_accuracy=0.99716

# %%
mod = NeuralNetwork(loss='binary_crossentropy', optimizer='gd', verbose=True, verbose_step=1)
mod.add(Flatten())
mod.add(Dense(784, activation='relu'))
mod.add(BatchNorm())
mod.add(Dense(784, activation='relu'))
mod.add(BatchNorm())
mod.add(Dense(1, activation='sigmoid'))
h = mod.fit(X_train, y_train, X_test, y_test, n_epochs=10, batch_size=128, metrics=['accuracy'])
plot_history(h)
# Out:
# ../activations.py:62: RuntimeWarning: overflow encountered in exp
#   return 1 / ((1 + np.exp(-X)) + self.bias)
# [    1/10]: loss=0.02616 val_loss=0.02592 accuracy=0.99853 val_accuracy=0.99684
# [    2/10]: loss=0.01201 val_loss=0.00965 accuracy=0.99937 val_accuracy=0.99842
# [    3/10]: loss=0.01396 val_loss=0.00930 accuracy=0.99926 val_accuracy=0.99842
# [    4/10]: loss=0.01969 val_loss=0.00882 accuracy=0.99916 val_accuracy=0.99842
# [    5/10]: loss=0.01915 val_loss=0.00825 accuracy=0.99916 val_accuracy=0.99842
# [    6/10]: loss=0.01857 val_loss=0.00715 accuracy=0.99926 val_accuracy=0.99842
# [    7/10]: loss=0.01776 val_loss=0.00689 accuracy=0.99926 val_accuracy=0.99842
# [    8/10]: loss=0.01683 val_loss=0.00623 accuracy=0.99926 val_accuracy=0.99842
# [    9/10]: loss=0.01678 val_loss=0.00604 accuracy=0.99926 val_accuracy=0.99842
# [   10/10]: loss=0.01674 val_loss=0.00597 accuracy=0.99926 val_accuracy=0.99842
