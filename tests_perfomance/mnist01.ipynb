# %%
import sys
sys.path.append('..')
from nn import *
from viz import plot_history
from tools import train_test_split

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mnist01 = np.load('datasets/mnist01.npz')
X, y= mnist01['X'], mnist01['y']

# %%
plt.imshow(X[0]);

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)
X_train = (X_train.astype(np.float32) / 255.0)
X_test = ( X_test.astype(np.float32) / 255.0)

# %%
mod = NeuralNetwork(loss='binary_crossentropy', optimizer='gd', verbose=True, verbose_step=1)
mod.add(Flatten())
mod.add(Dense(784, activation='relu'))
mod.add(Dense(784, activation='relu'))
mod.add(Dense(1, activation='sigmoid'))

# %%
h = mod.fit(X_train, y_train, X_test, y_test, n_epochs=10, batch_size=128, metrics=['accuracy'])
plot_history(h)
# Out:
# [    1/10]: loss=0.35505 val_loss=0.35480 accuracy=0.99326 val_accuracy=0.99242
# [    2/10]: loss=0.03087 val_loss=0.03148 accuracy=0.99737 val_accuracy=0.99684
# [    3/10]: loss=0.01426 val_loss=0.01580 accuracy=0.99758 val_accuracy=0.99747
# [    4/10]: loss=0.01000 val_loss=0.01201 accuracy=0.99800 val_accuracy=0.99811
# [    5/10]: loss=0.00802 val_loss=0.01034 accuracy=0.99800 val_accuracy=0.99811
# [    6/10]: loss=0.00683 val_loss=0.00938 accuracy=0.99842 val_accuracy=0.99811
# [    7/10]: loss=0.00603 val_loss=0.00875 accuracy=0.99863 val_accuracy=0.99811
# [    8/10]: loss=0.00544 val_loss=0.00831 accuracy=0.99874 val_accuracy=0.99811
# [    9/10]: loss=0.00498 val_loss=0.00797 accuracy=0.99884 val_accuracy=0.99811
# [   10/10]: loss=0.00462 val_loss=0.00770 accuracy=0.99895 val_accuracy=0.99811
